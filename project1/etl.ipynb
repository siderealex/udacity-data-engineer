# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host='localhost' port=5432 dbname='udacity_project2'")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('./data/song_data/')

# %%
filepath = song_files[0]

print(filepath)
# Out:
# /Users/codesw1tch/dev/udacity-data-engineer/project1/data/song_data/A/A/A/TRAAAEF128F4273421.json

# %%
df = pd.read_json(filepath, typ='ser').to_frame()
df.head()
# Out:
#                                    0
# num_songs                          1
# artist_id         AR7G5I41187FB4CE6C
# artist_latitude                 None
# artist_longitude                None
# artist_location      London, England

# %%
df.index
# Out:
# Index(['num_songs', 'artist_id', 'artist_latitude', 'artist_longitude',
#        'artist_location', 'artist_name', 'song_id', 'title', 'duration',
#        'year'],
#       dtype='object')

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
df[0]['num_songs']
# Out:
# 1

# %%
song_data = df[0][['song_id', 'title', 'artist_id', 'year', 'duration']].values.tolist()
song_data
# Out:
# ['SONHOTT12A8C13493C',
#  'Something Girls',
#  'AR7G5I41187FB4CE6C',
#  1982,
#  233.40363]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
df[0]
# Out:
# num_songs                            1
# artist_id           AR7G5I41187FB4CE6C
# artist_latitude                   None
# artist_longitude                  None
# artist_location        London, England
# artist_name                   Adam Ant
# song_id             SONHOTT12A8C13493C
# title                  Something Girls
# duration                       233.404
# year                              1982
# Name: 0, dtype: object

# %%
artist_data = df[0][['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']].values.tolist()
artist_data
# Out:
# ['AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', None, None]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('./data/log_data')

# %%
filepath = log_files[2]
print(filepath)
# Out:
# /Users/codesw1tch/dev/udacity-data-engineer/project1/data/log_data/2018/11/2018-11-18-events.json

# %%
df = pd.read_json(filepath, lines=True)

df.head()
# Out:
#                 artist       auth firstName gender  itemInSession  lastName  \
# 0  Great Lake Swimmers  Logged In     Kevin      M              0  Arellano
# 1  Soziedad Alkoholika  Logged In     Kevin      M              1  Arellano
# 2      Franz Ferdinand  Logged In     Kevin      M              2  Arellano
# 3         Modest Mouse  Logged In     Kevin      M              3  Arellano
# 4         Adam Lambert  Logged In     Kevin      M              4  Arellano
#
#       length level                 location method      page  registration  \
# 0  215.11791  free  Harrisburg-Carlisle, PA    PUT  NextSong  1.540007e+12
# 1  204.74730  free  Harrisburg-Carlisle, PA    PUT  NextSong  1.540007e+12
# 2  172.01587  free  Harrisburg-Carlisle, PA    PUT  NextSong  1.540007e+12
# 3  209.52771  free  Harrisburg-Carlisle, PA    PUT  NextSong  1.540007e+12
# 4  266.44853  free  Harrisburg-Carlisle, PA    PUT  NextSong  1.540007e+12
#
#    sessionId                       song  status             ts  \
# 0        815           Your Rocky Spine     200  1542931645796
# 1        815                    Va Bien     200  1542931860796
# 2        815  Eleanor Put Your Boots On     200  1542932064796
# 3        815                   Float On     200  1542932236796
# 4        815                  Aftermath     200  1542932445796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 1  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 2  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 3  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 4  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
# Filter out incomplete records
df = df[df['page'] == 'NextSong']
df.head()
# Out:
#                       artist       auth firstName gender  itemInSession  \
# 0                   Frumpies  Logged In  Anabelle      F              0
# 1  Kenny G with Peabo Bryson  Logged In  Anabelle      F              1
# 2                Biffy Clyro  Logged In  Anabelle      F              2
# 4                        HIM  Logged In      Lily      F              1
# 5                     Matmos  Logged In    Joseph      M              0
#
#     lastName      length level                                     location  \
# 0    Simpson   134.47791  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 1    Simpson   264.75057  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 2    Simpson   189.83138  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 4      Burns   212.06159  free        New York-Newark-Jersey City, NY-NJ-PA
# 5  Gutierrez  1449.11628  free                                 Columbia, SC
#
#   method      page  registration  sessionId                            song  \
# 0    PUT  NextSong  1.541044e+12        455                      Fuck Kitty
# 1    PUT  NextSong  1.541044e+12        455  By The Time This Night Is Over
# 2    PUT  NextSong  1.541044e+12        455                     God & Satan
# 4    PUT  NextSong  1.540621e+12        456                       Beautiful
# 5    PUT  NextSong  1.540809e+12        284                 Supreme Balloon
#
#    status             ts                                          userAgent  \
# 0     200  1541903636796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 1     200  1541903770796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2     200  1541904034796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1541910973796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 5     200  1541911006796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3...
#
#   userId
# 0     69
# 1     69
# 2     69
# 4     32
# 5     75

# %%
df.head()
# Out:
#                       artist       auth firstName gender  itemInSession  \
# 0                   Frumpies  Logged In  Anabelle      F              0
# 1  Kenny G with Peabo Bryson  Logged In  Anabelle      F              1
# 2                Biffy Clyro  Logged In  Anabelle      F              2
# 4                        HIM  Logged In      Lily      F              1
# 5                     Matmos  Logged In    Joseph      M              0
#
#     lastName      length level                                     location  \
# 0    Simpson   134.47791  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 1    Simpson   264.75057  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 2    Simpson   189.83138  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 4      Burns   212.06159  free        New York-Newark-Jersey City, NY-NJ-PA
# 5  Gutierrez  1449.11628  free                                 Columbia, SC
#
#   method      page  registration  sessionId                            song  \
# 0    PUT  NextSong  1.541044e+12        455                      Fuck Kitty
# 1    PUT  NextSong  1.541044e+12        455  By The Time This Night Is Over
# 2    PUT  NextSong  1.541044e+12        455                     God & Satan
# 4    PUT  NextSong  1.540621e+12        456                       Beautiful
# 5    PUT  NextSong  1.540809e+12        284                 Supreme Balloon
#
#    status             ts                                          userAgent  \
# 0     200  1541903636796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 1     200  1541903770796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2     200  1541904034796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1541910973796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 5     200  1541911006796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3...
#
#   userId
# 0     69
# 1     69
# 2     69
# 4     32
# 5     75

# %%
t = pd.to_datetime(df['ts'], unit='ms')

t.iloc[3]
# Out:
# Timestamp('2018-11-11 04:36:13.796000')

# %%
time_data = [t, t.dt.hour, t.dt.day, t.dt.week, t.dt.month, t.dt.year, t.dt.weekday]
column_labels = ['start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday']

# time_df = pd.DataFrame.from_records(data=time_data)

time_data[0].index[0]
# Out:
# 0

# %%
time_list = []
for n in range(len(time_data[0].index)):
    i = time_data[0].index[n]
    time_dict = {
        'start_time': time_data[0][i],
        'hour': time_data[1][i].item(),
        'day': time_data[2][i].item(),
        'week': time_data[3][i].item(),
        'month': time_data[4][i].item(),
        'year': time_data[5][i].item(),
        'weekday': time_data[6][i].item()
    }
    
    time_list.append(time_dict)

# %%
list(time_list[0].values())[1].item()
# Out:
# 2

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for row in time_list:
    cur.execute(time_table_insert, list(row.values()))
    conn.commit()
# Out:
# {'start_time': Timestamp('2018-11-11 02:33:56.796000'), 'hour': 2, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 02:36:10.796000'), 'hour': 2, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 02:40:34.796000'), 'hour': 2, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 04:36:13.796000'), 'hour': 4, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 04:36:46.796000'), 'hour': 4, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 09:56:28.796000'), 'hour': 9, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 10:00:47.796000'), 'hour': 10, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 10:04:07.796000'), 'hour': 10, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 10:08:28.796000'), 'hour': 10, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 10:12:00.796000'), 'hour': 10, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 10:27:43.796000'), 'hour': 10, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 10:33:44.796000'), 'hour': 10, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 10:36:22.796000'), 'hour': 10, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 10:40:14.796000'), 'hour': 10, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 10:43:23.796000'), 'hour': 10, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 10:46:18.796000'), 'hour': 10, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 11:14:51.796000'), 'hour': 11, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 13:41:22.796000'), 'hour': 13, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 13:52:23.796000'), 'hour': 13, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 13:58:22.796000'), 'hour': 13, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:05:43.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:07:54.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:09:36.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:14:29.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:15:06.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:17:52.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:19:37.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:24:58.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:30:05.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:33:53.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:37:16.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:40:58.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:44:29.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:47:24.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:47:42.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:51:55.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:54:07.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:56:21.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 14:57:24.796000'), 'hour': 14, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 15:00:12.796000'), 'hour': 15, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 15:00:37.796000'), 'hour': 15, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 15:04:26.796000'), 'hour': 15, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 15:07:26.796000'), 'hour': 15, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 15:10:12.796000'), 'hour': 15, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 15:14:56.796000'), 'hour': 15, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 16:01:19.796000'), 'hour': 16, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 16:05:35.796000'), 'hour': 16, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 16:09:12.796000'), 'hour': 16, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 16:13:43.796000'), 'hour': 16, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 18:08:33.796000'), 'hour': 18, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 18:48:12.796000'), 'hour': 18, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 18:49:01.796000'), 'hour': 18, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 18:51:56.796000'), 'hour': 18, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 18:53:36.796000'), 'hour': 18, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 18:54:46.796000'), 'hour': 18, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 19:41:45.796000'), 'hour': 19, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 19:45:25.796000'), 'hour': 19, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 19:48:53.796000'), 'hour': 19, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 19:56:23.796000'), 'hour': 19, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 19:59:18.796000'), 'hour': 19, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 20:03:09.796000'), 'hour': 20, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 20:06:02.796000'), 'hour': 20, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 20:08:52.796000'), 'hour': 20, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 20:13:22.796000'), 'hour': 20, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 20:15:55.796000'), 'hour': 20, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 20:19:18.796000'), 'hour': 20, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 20:22:03.796000'), 'hour': 20, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 20:25:40.796000'), 'hour': 20, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 21:09:28.796000'), 'hour': 21, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 21:13:48.796000'), 'hour': 21, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 21:17:29.796000'), 'hour': 21, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 23:39:00.796000'), 'hour': 23, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}
# {'start_time': Timestamp('2018-11-11 23:42:28.796000'), 'hour': 23, 'day': 11, 'week': 45, 'month': 11, 'year': 2018, 'weekday': 6}

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
df.columns
# Out:
# Index(['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName',
#        'length', 'level', 'location', 'method', 'page', 'registration',
#        'sessionId', 'song', 'status', 'ts', 'userAgent', 'userId'],
#       dtype='object')

# %%
# Only select columns we need for users table, and drop duplicate users
user_df = df[['userId', 'firstName', 'lastName', 'gender', 'level']].drop_duplicates(subset='userId')

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for index, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
df.head()
# Out:
#                       artist       auth firstName gender  itemInSession  \
# 0                   Frumpies  Logged In  Anabelle      F              0
# 1  Kenny G with Peabo Bryson  Logged In  Anabelle      F              1
# 2                Biffy Clyro  Logged In  Anabelle      F              2
# 4                        HIM  Logged In      Lily      F              1
# 5                     Matmos  Logged In    Joseph      M              0
#
#     lastName      length level                                     location  \
# 0    Simpson   134.47791  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 1    Simpson   264.75057  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 2    Simpson   189.83138  free  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 4      Burns   212.06159  free        New York-Newark-Jersey City, NY-NJ-PA
# 5  Gutierrez  1449.11628  free                                 Columbia, SC
#
#   method      page  registration  sessionId                            song  \
# 0    PUT  NextSong  1.541044e+12        455                      Fuck Kitty
# 1    PUT  NextSong  1.541044e+12        455  By The Time This Night Is Over
# 2    PUT  NextSong  1.541044e+12        455                     God & Satan
# 4    PUT  NextSong  1.540621e+12        456                       Beautiful
# 5    PUT  NextSong  1.540809e+12        284                 Supreme Balloon
#
#    status             ts                                          userAgent  \
# 0     200  1541903636796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 1     200  1541903770796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2     200  1541904034796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1541910973796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 5     200  1541911006796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3...
#
#   userId
# 0     69
# 1     69
# 2     69
# 4     32
# 5     75

# %%
for index, row in df.iterrows():
    # Get songid and artistid from song and artist tables
    results = cur.execute(song_select, [row['song'], row['artist'], row['length']])
    song_id, artist_id = results if results else None, None
    
    # Insert songplay record
    songplay_data = (
        pd.to_datetime(row['ts'], unit='ms'), 
        row['userId'], 
        row['level'], 
        song_id, 
        artist_id, 
        row['sessionId'], 
        row['location'], 
        row['userAgent']
    )
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# <ipython-input-83-14c54bf237a9> in <module>
#      16         row['userAgent']
#      17     )
# ---> 18     cur.execute(songplay_table_insert, songplay_data)
#      19     conn.commit()
#
# UniqueViolation: duplicate key value violates unique constraint "songplays_pkey"
# DETAIL:  Key (songplay_id)=(0) already exists.

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
